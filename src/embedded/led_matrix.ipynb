# %%
%esptool erase
# Out:
# Found serial ports /dev/cu.usbserial-0236E4D9, /dev/cu.Bluetooth-Incoming-Port, /dev/cu.wlan-debug:
# Executing:
#   esptool.py --port /dev/cu.usbserial-0236E4D9 erase_flash
#
# esptool.py v4.8.1
# Serial port /dev/cu.usbserial-0236E4D9
# Connecting....
# [Press the PRG button now if required]
# Detecting chip type... Unsupported detection protocol, switching and trying again...
# Connecting.....
# [Press the PRG button now if required]
# Detecting chip type... ESP32
# Chip is ESP32-D0WDQ6-V3 (revision v3.0)
# Features: WiFi, BT, Dual Core, 240MHz, VRef calibration in efuse, Coding Scheme None
# Crystal is 40MHz
# MAC: 94:b9:7e:d2:f6:d0
# Uploading stub...
# Running stub...
# Stub running...
# Erasing flash (this may take a while)...
# Chip erase completed successfully in 3.7s
# Hard resetting via RTS pin...

# %%
%esptool esp32 /Users/abhinabray/Downloads/ESP32_GENERIC-20240602-v1.23.0.bin
# Out:
# Found serial ports /dev/cu.usbserial-0236E4D9, /dev/cu.Bluetooth-Incoming-Port, /dev/cu.wlan-debug:
# Executing:
#   esptool.py --port /dev/cu.usbserial-0236E4D9 --chip esp32 write_flash -z 0x1000 /Users/abhinabray/Downloads/ESP32_GENERIC-20240602-v1.23.0.bin
#
# esptool.py v4.8.1
# Serial port /dev/cu.usbserial-0236E4D9
# Connecting....
# [Press the PRG button now if required]
# Chip is ESP32-D0WDQ6-V3 (revision v3.0)
# Features: WiFi, BT, Dual Core, 240MHz, VRef calibration in efuse, Coding Scheme None
# Crystal is 40MHz
# MAC: 94:b9:7e:d2:f6:d0
# Uploading stub...
# Running stub...
# Stub running...
# Configuring flash size...
# Flash will be erased from 0x00001000 to 0x001a8fff...
# Compressed 1734240 bytes to 1142447...
# Writing at 0x00001000... (1 %)
# Writing at 0x00010a98... (2 %)
# Writing at 0x00018b5e... (4 %)
# Writing at 0x00020d39... (5 %)
#
# Lost connection, retrying...
# Waiting for the chip to reconnect
# Connecting....
# [Press the PRG button now if required]
# ...

# %%
%disconnect

# %%
%serialconnect --port /dev/tty.usbserial-0236E4D9
# Out:
# Connecting to --port=/dev/tty.usbserial-0236E4D9 --baud=115200 could not open port /dev/tty.usbserial-0236E4D9: [Errno 2] No such file or directory: '/dev/tty.usbserial-0236E4D9'
#
# Try one of these ports as --port=
#   /dev/cu.usbserial-02215408
#   /dev/cu.Bluetooth-Incoming-Port
#   /dev/cu.wlan-debug

# %%
%ls

# %%
%sendtofile --source boot.py boot.py
# Out:
# Sent 420 lines (16309 bytes) to boot.py.

# %%
%lsmagic
